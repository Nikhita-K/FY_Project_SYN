# %%
import matplotlib.pyplot as plt

# %%
# x-coordinates of left sides of bars 
left = ['Naive Bayes','Enc NB','KNN','Enc KNN', 'Random Forest','Enc RF', 'Decision Tree', 'Enc DT','Logistic Regression','Enc LR', 'SVM','Enc SVM']

# %%
# heights of bars    ##plain_enc_accuracy=[50.75,64.44,70.15,57.78,61.19,62.22,70.15,57.78,79.1,57.78,58.21,60]
#acc = [50.75,64.44,58.21,60,70.15,57.78,61.19,62.22,70.15,57.78,79.1,57.78]
acc=[73.13,57.78,67.16,48.89,86.57,75.56,76.12,71.11,80.6,60.0,77.61,57.78]

# %%
# labels for bars
label = ['Naive Bayes','Enc NB','KNN','Enc KNN', 'Random Forest','Enc RF', 'Decision Tree', 'Enc DT','Logistic Regression','Enc LR', 'SVM','Enc SVM']

# %%
# plotting a bar chart
plt.figure(figsize=(16,7))
plt.bar(left, acc, label = label,
        width = 0.8, color=['lightpink','pink','purple','plum', 'paleturquoise','blue','aquamarine','grey','mistyrose','red','moccasin','yellow'])
# naming the x-axis
plt.xlabel('x - axis')
# naming the y-axis
plt.ylabel('y - axis')
# plot title
plt.title('Accuracy Comparison Plot')
  
# function to show the plot
plt.show()

# %%
left_e = ['Naive Bayes','KNN', 'Random Forest', 'Decision Tree', 'Logistic Regression', 'SVM']

# %%
#acc_e = [60,57.78, 62.22, 73.33, 68.89, 77.78]
#acc_e=[64.44,60,57.78,62.22,57.78,57.78]   
acc_e=[57.78,48.89,75.56,71.11,60.0,57.78]

# %%
label_e = ['Naive Bayes','KNN', 'Random Forest', 'Decision Tree', 'Logistic Regression', 'SVM']

# %%
plt.figure(figsize=(14,7))
plt.bar(left_e, acc_e, label = label_e,
        width =0.6, color=['lightpink', 'purple','paleturquoise','aquamarine','mistyrose','moccasin'])
# naming the x-axis
plt.xlabel('x - axis')
# naming the y-axis
plt.ylabel('y - axis')
# plot title
plt.title('My bar chart!')
  
# function to show the plot
plt.show()

# %%
# line 1 points
plt.figure(figsize=(14,7))
#acc_p=[50.75,70.15, 64.18, 64.18, 59.7, 70.15]
acc_p=[73.13,67.16,86.57,76.12,80.6,77.61]
x1 = label_e
y1 = acc_p
# plotting the line 1 points 
plt.plot(x1, y1, label = "Accuracy on Classification Of plain text")
  
# line 2 points
x2 = label_e
y2 = acc_e
# plotting the line 2 points 
plt.plot(x2, y2, label = "Accuracy on Classification Of encrypted text")
  
# naming the x axis
plt.xlabel('Classification Algorithms')
# naming the y axis
plt.ylabel('Accuracy')
# giving a title to my graph
plt.title('Accuracy Graph')
  
# show a legend on the plot
plt.legend()
  
# function to show the plot
plt.show()
